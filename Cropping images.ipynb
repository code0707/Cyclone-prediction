# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
shear_range = 0.2,
zoom_range = 0.2,
horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory('C:/Users/KIIT/Desktop/cyclone/train',
target_size = (64,64),
batch_size = 32,
class_mode = 'binary')
test_set = test_datagen.flow_from_directory('C:/Users/KIIT/Desktop/cyclone/test',
target_size = (64,64),
batch_size = 32,
class_mode = 'binary')

# %%
import pandas as pd

# %%
training_set[0][0][2].shape
# Out:
# (64, 64, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(training_set[0][0][0],cmap='gray')

# %%
from PIL import Image
im = Image.open("C:/Users/KIIT/Desktop/dsc/training/1/image72.jpg")

crop_rectangle = (870,260, 970, 350)
cropped_im = im.crop(crop_rectangle)

cropped_im.show()

# %%
training_set[0][0][0]=cropped_im

# %%
cropped_im
# Out:
# <PIL.Image.Image image mode=RGB size=100x90 at 0x17C799099E8>

# %%
from sklearn.model_selection import train_test_split

# %%
x=list(range(1,360))
y=list(range(1,360))

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=42)

# %%
train_test_split(y, shuffle=False)

# %%
for count in range(1,360):
    
    im = Image.open("C:/Users/KIIT/Desktop/dummy/image"+str(count)+".jpg")
    crop_rectangle = (870,260, 970, 350)
    cropped_im = im.crop(crop_rectangle)


    if (count in [72,73,202,203,204,219,220,227,228,229,249,250,262,263,264,265,281,282,283,284,285,347,348]):
        
        if(count in y_train):
            cropped_im.save('C:/Users/KIIT/Desktop/cyclone/train/1/'+str(count)+'.jpg', 'JPEG')
        else:
            cropped_im.save('C:/Users/KIIT/Desktop/cyclone/test/1/'+str(count)+'.jpg', 'JPEG')

    else:
        if(count in y_train):
            cropped_im.save('C:/Users/KIIT/Desktop/cyclone/train/0/'+str(count)+'.jpg', 'JPEG')
        else:
            cropped_im.save('C:/Users/KIIT/Desktop/cyclone/test/0/'+str(count)+'.jpg', 'JPEG')
